# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

# %%
import sys
sys.path.append('Library/bin/')

import matplotlib.pyplot as plt
import mhp1_analysis as mpa

# %%
top_dir = 'simulations/dims/implicit_solvent/implicit_membrane/run/in_occ_out/005/'
mpa.gates('full_dims_mhp1_i2occ2o.dcd', top=top_dir+'2jln_r10_g470_c22.psf')
# Out:
# /usr/local/lib/python2.7/dist-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /usr/local/lib/python2.7/dist-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):

# %%
plt.show()

# %%
project_dir = '/nfs/homes/tcolburn/Projects/Beckstein/Mhp1/'
data_dir = project_dir + 'simulations/dims/implicit_solvent/implicit_membrane/run/in_occ_out/005/'
trj_dir = data_dir + 'traj_005/'
top_dir = data_dir

# %%
top = top_dir + '2jln_r10_g470_c22.psf'
# traj = trj_dir + 'full_dims_mhp1_i2occ2o.dcd'
traj = project_dir + '/full_dims_mhp1_i2occ2o.dcd'
mpa.gates(traj, top=top)
